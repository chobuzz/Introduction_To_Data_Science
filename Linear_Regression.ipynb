# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
companies = pd.read_csv('C:/Users/chobu/Desktop/AI/Data_Science_simplilearn/data/1000_companies.csv')

# %%
companies.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X = companies.iloc[:, :-1].values
y = companies.iloc[:, 4].values

# %%
sns.heatmap(companies.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
X = enc.fit_transform(X[:, 3].reshape(-1,1))

# %%
companies[['State']].value_counts()
# Out:
# State
# California    344
# New York      334
# Florida       322
# Name: count, dtype: int64

# %%
type(companies)
# Out:
# pandas.core.frame.DataFrame

# %%
X
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.],
#        ...,
#        [1., 0., 0.],
#        [1., 0., 0.],
#        [0., 0., 1.]])
